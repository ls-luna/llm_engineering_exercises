# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
# Out:
# API key looks good so far

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer
openai = OpenAI()
ai_tutor_system_prompt = "You are a helpful assistant that explains code."

def ai_tutor(question):
    response = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=[
            {"role": "system", "content": ai_tutor_system_prompt},
            {"role": "user", "content": question}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))
    
ai_tutor(question);

# %%
# Get gpt-4o-mini to answer, with streaming
openai = OpenAI()
ai_tutor_system_prompt = "You are a helpful assistant that explains code."

def ai_tutor(question):
    stream = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=[
            {"role": "system", "content": ai_tutor_system_prompt},
            {"role": "user", "content": question}
        ],
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)
    return response

ai_tutor(question);
# Out:
# The provided code is a single line that utilizes a generator expression in Python. Let's break it down step by step:
#
# ### Breakdown of the Code
#
# 1. **Set Comprehension**:
#    - `{book.get("author") for book in books if book.get("author")}` is a set comprehension.
#    - This means it is creating a set of unique authors by iterating over a collection called `books`.
#
# 2. **Iteration**:
#    - `for book in books`: This part iterates over each `book` in the `books` collection. Here, `books` is expected to be an iterable (like a list) containing dictionaries representing books.
#
# 3. **Accessing Data**:
#    - `book.get("author")`: This accesses the value associated with the key `"author"` in each `book` dictionary.
#    - The `.get()` method is used instead of direct indexing (`book["author"]`) to avoid potential `KeyError`s if a dictionary does not contain the key `"author"`. If the key is not found, it returns `None` (or a specified default value, if provided).
#
# 4. **Filtering**:
#    - `if book.get("author")`: This conditional checks that the result of `book.get("author")` is truthy (i.e., not `None`, `""`, or other falsy values). Only `book` entries that have an author specified will be included in the resulting set.
#
# 5. **Creating a Set**:
#    - The expression results in a set of authors, effectively collecting all unique authors found in the `books` collection.
#
# 6. **Yielding from the Set**:
#    - `yield from ...`: The `yield from` statement is used to yield each item from the set that was created by the set comprehension.
#    - This means that if this line is within a generator function, it will yield each unique author one by one to the caller.
#
# ### Purpose of the Code
#
# - The overall purpose of this code is to create a generator that yields unique authors from a collection of books. It navigates through the list of books, fetches the authors while ensuring that only non-blank (truthy) authors are included, and handles the potential absence of the `"author"` key gracefully.
# - This can be particularly useful in scenarios where you want to collect and process the names of unique authors without duplicates, such as creating an authors list, sending emails, or generating reports.
#
# ### Example Usage
#
# If you had the following list of books:
#
# ```python
# books = [
#     {"title": "Book 1", "author": "Author A"},
#     {"title": "Book 2", "author": "Author B"},
#     {"title": "Book 3", "author": "Author A"},
#     {"title": "Book 4"},  # no author key
#     {"title": "Book 5", "author": ""}
# ]
# ```
#
# Using the provided line of code, the resulting set of authors would be `{"Author A", "Author B"}`, and it would yield these authors one by one if used within a generator function.

# %%
# Get Llama 3.2 to answer
